# %% [markdown]
# <a href="https://colab.research.google.com/github/GPTJunkie/Comic-Smart-Panels/blob/master/Sora_2_Video_Watermark_Remover_Free.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install iopaint
# Out:
# ...
# WARNING: typer 0.24.1 does not provide the extra 'all'
# ...

# %%
# !iopaint download --model lama
# Out:
# 2026-04-14 02:00:25.103 | INFO     | iopaint.runtime:setup_model_dir:81 - Model directory: /root/.cache
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776132038.577197    2965 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776132038.588475    2965 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776132038.609778    2965 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !curl -sL https://github.com/GitHub30/Sora2WatermarkRemover/archive/refs/heads/main.tar.gz | tar xz --strip-components=1

# %% [markdown]
# # Upload your Sora 2 video

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-bac8f111-bc65-492d-a88d-68a071a93026" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bac8f111-bc65-492d-a88d-68a071a93026">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python remwm.py *.mp4 ./out.mp4 --max-bbox-percent=15 --force-format=MP4
# Out:
# 2026-04-14 02:08:25.423171: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776132505.444311    5107 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776132505.451019    5107 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776132505.469325    5107 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
files.download('out.mp4')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2724/2277102952.py in <cell line: 0>()
# ----> 1 files.download('out.mp4')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: out.mp4
